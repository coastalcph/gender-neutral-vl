# %% [markdown]
# ## Plot tasks
#
# Code to generate figures presented in Figure 3 (Group performance is depicted in Figure 3 for a subset of models and tasks). Results are from running the corresponding scripts in the `experiments/` folder.

# %%
import numpy as np
import pandas as pd
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
from matplotlib.ticker import MaxNLocator
import matplotlib.patches as mpatches

matplotlib.rcParams['text.usetex'] = True
plt.rc('font', family='serif', serif=['Times'])

cm = plt.get_cmap('Set3') 
colors = cm.colors

# %%
models = [
    '$\\mathrm{\\textsc{LXMERT}_{180K}}$', #0
    '$\\mathrm{\\textsc{LXMERT}_{180K}^{N}}$', #1
    '$\\mathrm{\\textsc{LXMERT}_{3M}}$', #2
    '$\\mathrm{\\textsc{LXMERT}_{3M}^{N}}$', #3
    '$\\mathrm{\\textsc{ALBEF}_{4M}}$', #4
    '$\\mathrm{\\textsc{ALBEF}_{4M}^{N-COCO}}$', #5
    '$\\mathrm{\\textsc{ALBEF}_{4M}^{N-CC3M}}$', #6
    '$\\mathrm{\\textsc{ALBEF}_{14M}}$', #7
    '$\\mathrm{\\textsc{ALBEF}_{14M}^{N-COCO}}$', #8
    '$\\mathrm{\\textsc{ALBEF}_{14M}^{N-CC3M}}$', #9
    '$\\mathrm{\\textsc{BLIP}_{129M}}$', #10
    '$\\mathrm{\\textsc{BLIP}_{129M}^{N}}$' #11
]

# %% [markdown]
# # VQAv2

# %%
lxmert = {"M": 77.5, "F": 76.3, "N": 72.7}
lxmert_n = {"M": 79.6, "F":78.1, "N":79.3}
lxmert_3m = {"M":68.4, "F":66.5, "N":62.4}
lxmert_3m_n = {"M":70.3, "F":67.9, "N":70.1}
albef14m = {"M":76.0, "F":75.0, "N":75.6}
albef14m_coco_n = {"M":76.0, "F":74.9, "N":75.5}
albef14m_cc3m_n = {"M":75.8, "F":75.0, "N":75.5}
blip = {"M":76.5, "F":75.1, "N":75.6}
blip_n = {"M":76.4, "F":75.2, "N":75.8}

fig = plt.figure(figsize=(6,6), tight_layout=True)
ax = fig.add_subplot()

bcm = plt.get_cmap('Pastel2')
bcolors = bcm.colors
ax.set_xlim(-0.5, 2.5)
ax.axvspan(-0.5, 0.5, facecolor=bcolors[0], alpha=0.2)
ax.axvspan(0.5, 1.5, facecolor=bcolors[1], alpha=0.3)
ax.axvspan(1.5, 2.5, facecolor=bcolors[2], alpha=0.2)

w = 0.25
size=14
j = 0.1

# LXMERT
i = 0
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])

# ALBEF
i = 1
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["M"], 'D', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["F"], 'D', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["N"], 'D', markersize=size, markeredgecolor='k', color=colors[1])


# BLIP
i = 2
ax.plot(i-w + np.random.rand(1)[0]*j, blip["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


ax.set_ylim(70, 81)
ax.set_xticks([x for x in range(3)])
ax.set_xticklabels([models[0], models[7], models[10]], fontsize=20)
ax.tick_params(axis="y", labelsize=18)
ax.grid(color='gray', alpha=0.2)

h = [Patch(facecolor=colors[0], edgecolor='k', label='male'),
     Patch(facecolor=colors[3], edgecolor='k', label='female'),
     Patch(facecolor=colors[1], edgecolor='k', label='neutral')]
leg2 = ax.legend(handles=h, ncol=1, scatterpoints=1, fontsize=16, loc='lower right')
# ax.add_artist(leg1)

# plt.savefig('figures/vqa_selection_gender.pdf', bbox_extra_artists=(leg1,), bbox_inches='tight')
plt.savefig('figures/vqa_selection_gender_coco.pdf', bbox_inches='tight')

# %% [markdown]
# # GQA

# %%
lxmert = {"M": 83.8, "F": 84.9, "N": 84.8}
lxmert_n = {"M": 83.9, "F": 85.4, "N": 85.3}
lxmert_3m = {"M": 63.7, "F": 65.6, "N": 64.5}
lxmert_3m_n = {"M": 64.6, "F": 66.8, "N": 64.5}
albef14m = {"M": 59.7, "F": 59.6, "N": 62.4}
albef14m_coco_n = {"M": 60.6, "F": 60.3, "N": 62.7}
albef14m_cc3m_n = {"M": 60.7, "F": 61.9, "N": 63.0}
blip = {"M": 60.3, "F": 60.3, "N": 62.3}
blip_n = {"M": 60.1, "F": 59.7, "N": 62.3}

data_ = [lxmert, lxmert_3m, albef14m, blip,
         lxmert_n, lxmert_3m_n, 
         albef14m_coco_n, albef14m_cc3m_n,
         blip_n]
index_ = ["lxmert", "lxmert_3m", "albef14m", "blip", 
          "lxmert_n", "lxmert_3m_n", 
          "albef14m_coco_n", "albef14m_cc3m_n", 
          "blip_n"]
df = pd.DataFrame(data=data_, 
                  index=index_)
df
# Out:
#                     M     F     N
# lxmert           83.8  84.9  84.8
# lxmert_3m        63.7  65.6  64.5
# albef14m         59.7  59.6  62.4
# blip             60.3  60.3  62.3
# lxmert_n         83.9  85.4  85.3
# lxmert_3m_n      64.6  66.8  64.5
# albef14m_coco_n  60.6  60.3  62.7
# albef14m_cc3m_n  60.7  61.9  63.0
# blip_n           60.1  59.7  62.3

# %%
fig = plt.figure(figsize=(6,6), tight_layout=True)
ax = fig.add_subplot()

bcm = plt.get_cmap('Pastel2')
bcolors = bcm.colors
ax.set_xlim(-0.5, 2.5)
ax.axvspan(-0.5, 0.5, facecolor=bcolors[0], alpha=0.2)
ax.axvspan(0.5, 1.5, facecolor=bcolors[1], alpha=0.3)
ax.axvspan(1.5, 2.5, facecolor=bcolors[2], alpha=0.2)

w = 0.25
size=14
j = 0.1

# LXMERT
i = 0
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])

# ALBEF
i = 1
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["M"], 'D', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["F"], 'D', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["N"], 'D', markersize=size, markeredgecolor='k', color=colors[1])

# BLIP
i = 2
ax.plot(i-w + np.random.rand(1)[0]*j, blip["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


ax.set_ylim(58,87)
ax.set_xticks([x for x in range(3)])
ax.set_xticklabels([models[0], models[7], models[10]], fontsize=18)
ax.tick_params(axis="y", labelsize=18)
ax.grid(color='gray', alpha=0.2)


h = [Patch(facecolor=colors[0], edgecolor='k', label='male'),
     Patch(facecolor=colors[3], edgecolor='k', label='female'),
     Patch(facecolor=colors[1], edgecolor='k', label='neutral')]
leg2 = ax.legend(handles=h, ncol=1, scatterpoints=1, fontsize=16, loc='upper right')

plt.savefig('figures/gqa_selection_gender_coco.pdf', bbox_inches='tight')

# %% [markdown]
# # NLVR2

# %%
lxmert = {"M": 81.9, "F": 75.0, "N": 81.1}
lxmert_n = {"M": 79.3, "F": 74.2, "N": 80.2}
lxmert_3m = {"M": 72.3, "F": 64.0, "N": 78.8}
lxmert_3m_n = {"M": 79.3, "F": 67.7, "N": 78.8}
albef14m = {"M": 86.8, "F": 79.8, "N": 81.2}
albef14m_coco_n = {"M": 60.4, "F": 52.5, "N": 57.6}
albef14m_cc3m_n = {"M": 87.9, "F": 77.8, "N": 81.7}
blip = {"M": 82.4, "F": 77.8, "N": 83.8}
blip_n = {"M": 84.6, "F": 73.7, "N": 80.9}

data_ = [lxmert, lxmert_3m, albef14m, blip,
         lxmert_n, lxmert_3m_n, 
         albef14m_coco_n, albef14m_cc3m_n,
         blip_n]
index_ = ["lxmert", "lxmert_3m", "albef14m", "blip", 
          "lxmert_n", "lxmert_3m_n", 
          "albef14m_coco_n", "albef14m_cc3m_n", 
          "blip_n"]
df = pd.DataFrame(data=data_, 
                  index=index_)
df
# Out:
#                     M     F     N
# lxmert           81.9  75.0  81.1
# lxmert_3m        72.3  64.0  78.8
# albef14m         86.8  79.8  81.2
# blip             82.4  77.8  83.8
# lxmert_n         79.3  74.2  80.2
# lxmert_3m_n      79.3  67.7  78.8
# albef14m_coco_n  60.4  52.5  57.6
# albef14m_cc3m_n  87.9  77.8  81.7
# blip_n           84.6  73.7  80.9

# %%
fig = plt.figure(figsize=(6,6), tight_layout=True)
ax = fig.add_subplot()

bcm = plt.get_cmap('Pastel2')
bcolors = bcm.colors
ax.set_xlim(-0.5, 2.5)
ax.axvspan(-0.5, 0.5, facecolor=bcolors[0], alpha=0.2)
ax.axvspan(0.5, 1.5, facecolor=bcolors[1], alpha=0.3)
ax.axvspan(1.5, 2.5, facecolor=bcolors[2], alpha=0.2)


w = 0.25
size=14
j = 0.1

# LXMERT
i = 0
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])

# ALBEF
i = 1
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["M"], 'D', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["F"], 'D', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["N"], 'D', markersize=size, markeredgecolor='k', color=colors[1])



# BLIP
i = 2
ax.plot(i-w + np.random.rand(1)[0]*j, blip["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


ax.set_ylim(50,90)
ax.set_xticks([x for x in range(3)])
ax.set_xticklabels([models[0], models[7], models[10]], fontsize=18)
ax.tick_params(axis="y", labelsize=18)
ax.grid(color='gray', alpha=0.2)

h = [Patch(facecolor=colors[0], edgecolor='k', label='male'),
     Patch(facecolor=colors[3], edgecolor='k', label='female'),
     Patch(facecolor=colors[1], edgecolor='k', label='neutral')]
leg2 = ax.legend(handles=h, ncol=1, scatterpoints=1, fontsize=16, loc='lower right')
# ax.add_artist(leg1)

# plt.savefig('figures/nlvr_selection_gender.pdf', bbox_extra_artists=(leg1,), bbox_inches='tight')
plt.savefig('figures/nlvr_selection_gender_coco.pdf', bbox_inches='tight')

# %% [markdown]
# # F30K

# %%
# IR - Image Retrieval
lxmert = {"M": 55.8, "F": 58.5, "N": 48.4}
lxmert_n = {"M": 56.1, "F": 58.1, "N": 49.3}
lxmert_3m = {"M": 56.0, "F": 59.4, "N": 51.2}
lxmert_3m_n = {"M": 51.4, "F": 52.3, "N": 47.3}
albef14m = {"M":87.5, "F": 89.1, "N": 81.8}
albef14m_coco_n = {"M": 86.6, "F": 87.8, "N": 81.9}
albef14m_cc3m_n = {"M": 86.6, "F": 89.8, "N": 82.0}
blip = {"M": 88.7, "F": 90.6, "N": 84.4}
blip_n = {"M": 88.1, "F": 89.6, "N": 83.8}

data_ = [lxmert, lxmert_3m, albef14m, blip,
         lxmert_n, lxmert_3m_n, 
         albef14m_coco_n, albef14m_cc3m_n,
         blip_n]
index_ = ["lxmert", "lxmert_3m", "albef14m", "blip", 
          "lxmert_n", "lxmert_3m_n", 
          "albef14m_coco_n", "albef14m_cc3m_n", 
          "blip_n"]
df = pd.DataFrame(data=data_, 
                  index=index_)
df
# Out:
#                     M     F     N
# lxmert           55.8  58.5  48.4
# lxmert_3m        56.0  59.4  51.2
# albef14m         87.5  89.1  81.8
# blip             88.7  90.6  84.4
# lxmert_n         56.1  58.1  49.3
# lxmert_3m_n      51.4  52.3  47.3
# albef14m_coco_n  86.6  87.8  81.9
# albef14m_cc3m_n  86.6  89.8  82.0
# blip_n           88.1  89.6  83.8

# %%
fig = plt.figure(figsize=(6,6), tight_layout=True)
ax = fig.add_subplot()


bcm = plt.get_cmap('Pastel2')
bcolors = bcm.colors
ax.set_xlim(-0.5, 2.5)
ax.axvspan(-0.5, 0.5, facecolor=bcolors[0], alpha=0.2)
ax.axvspan(0.5, 1.5, facecolor=bcolors[1], alpha=0.3)
ax.axvspan(1.5, 2.5, facecolor=bcolors[2], alpha=0.2)


w = 0.25
size=14
j = 0.1

# LXMERT
i = 0
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


# ALBEF
i = 1
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["M"], 'D', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["F"], 'D', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["N"], 'D', markersize=size, markeredgecolor='k', color=colors[1])


# BLIP
i = 2
ax.plot(i-w + np.random.rand(1)[0]*j, blip["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


ax.set_ylim(48,92)
ax.set_xticks([x for x in range(3)])
ax.set_xticklabels([models[0], models[7], models[10]], fontsize=18)
ax.tick_params(axis="y", labelsize=18)
ax.grid(color='gray', alpha=0.2)

ax.plot([], [], color='gray', marker='o', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}}$')
ax.plot([], [], color='gray', marker='s', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}^{N}}$')
ax.plot([], [], color='gray', marker='D', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}^{N\'}}$')
leg1 = ax.legend(ncol=1, scatterpoints=1, fontsize=18, bbox_to_anchor=(1.26, 0.5),
                 loc='center right', handletextpad=0)

h = [Patch(facecolor=colors[0], edgecolor='k', label='male'),
     Patch(facecolor=colors[3], edgecolor='k', label='female'),
     Patch(facecolor=colors[1], edgecolor='k', label='neutral')]
leg2 = ax.legend(handles=h, ncol=1, scatterpoints=1, fontsize=16, loc='lower right')
# ax.add_artist(leg1)

# plt.savefig('figures/f30kTR_selection_gender.pdf', bbox_extra_artists=(leg1,), bbox_inches='tight')
plt.savefig('figures/f30kIR_selection_gender_coco.pdf',bbox_inches='tight')

# %%
# TR - Text Retrieval
lxmert = {"M": 61.6, "F":62.8, "N":55.3}
lxmert_n = {"M":66.4, "F":67.6, "N":59.2 }
lxmert_3m = {"M":63.0, "F":63.7, "N":55.0 }
lxmert_3m_n = {"M":56.2, "F":61.4, "N":52.4 }
albef14m = {"M":95.9, "F":100.0, "N":94.0 }
albef14m_coco_n = {"M":95.4, "F":99.0, "N":94.0 }
albef14m_cc3m_n = {"M":95.9, "F":98.1, "N":93.5 }
blip = {"M":97.1, "F":99.0, "N":95.2 }
blip_n = {"M":98.3, "F":99.0, "N":94.9 }

data_ = [lxmert, lxmert_3m, albef14m, blip,
         lxmert_n, lxmert_3m_n, 
         albef14m_coco_n, albef14m_cc3m_n,
         blip_n]
index_ = ["lxmert", "lxmert_3m", "albef14m", "blip", 
          "lxmert_n", "lxmert_3m_n", 
          "albef14m_coco_n", "albef14m_cc3m_n", 
          "blip_n"]
df = pd.DataFrame(data=data_, 
                  index=index_)
df
# Out:
#                     M      F     N
# lxmert           61.6   62.8  55.3
# lxmert_3m        63.0   63.7  55.0
# albef14m         95.9  100.0  94.0
# blip             97.1   99.0  95.2
# lxmert_n         66.4   67.6  59.2
# lxmert_3m_n      56.2   61.4  52.4
# albef14m_coco_n  95.4   99.0  94.0
# albef14m_cc3m_n  95.9   98.1  93.5
# blip_n           98.3   99.0  94.9

# %%
fig = plt.figure(figsize=(6,6), tight_layout=True)
ax = fig.add_subplot()


bcm = plt.get_cmap('Pastel2')
bcolors = bcm.colors
ax.set_xlim(-0.5, 2.5)
ax.axvspan(-0.5, 0.5, facecolor=bcolors[0], alpha=0.2)
ax.axvspan(0.5, 1.5, facecolor=bcolors[1], alpha=0.3)
ax.axvspan(1.5, 2.5, facecolor=bcolors[2], alpha=0.2)

w = 0.25
size=14
j = 0.1

# LXMERT
i = 0
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i-w + np.random.rand(1)[0]*j, lxmert_3m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[2])
# ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_3m_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, lxmert["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, lxmert_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


# ALBEF
i = 1
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, albef14m["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i + np.random.rand(1)[0]*j, albef14m_coco_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["M"], 'D', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["F"], 'D', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, albef14m_cc3m_n["N"], 'D', markersize=size, markeredgecolor='k', color=colors[1])


# BLIP
i = 2
ax.plot(i-w + np.random.rand(1)[0]*j, blip["M"], 'o', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["F"], 'o', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i-w + np.random.rand(1)[0]*j, blip["N"], 'o', markersize=size, markeredgecolor='k', color=colors[1])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["M"], 's', markersize=size, markeredgecolor='k', color=colors[0])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["F"], 's', markersize=size, markeredgecolor='k', color=colors[3])
ax.plot(i+w + np.random.rand(1)[0]*j, blip_n["N"], 's', markersize=size, markeredgecolor='k', color=colors[1])


ax.set_ylim(53,100.5)
ax.set_xticks([x for x in range(3)])
ax.set_xticklabels(["LXMERT", "ALBEF", "BLIP"], fontsize=18)
ax.tick_params(axis="y", labelsize=18)
ax.grid(color='gray', alpha=0.2)

ax.plot([], [], color='gray', marker='o', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}}$')
ax.plot([], [], color='gray', marker='s', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}^{N}}$')
ax.plot([], [], color='gray', marker='D', linestyle='None', markersize=size, label='$\\mathrm{\\textsc{M}^{N\'}}$')
leg1 = ax.legend(ncol=1, scatterpoints=1, fontsize=18, bbox_to_anchor=(1.26, 0.5),
                 loc='center right', handletextpad=0)

h = [Patch(facecolor=colors[0], edgecolor='k', label='male'),
     Patch(facecolor=colors[3], edgecolor='k', label='female'),
     Patch(facecolor=colors[1], edgecolor='k', label='neutral')]
leg2 = ax.legend(handles=h, ncol=1, scatterpoints=1, fontsize=16, loc='lower right')
# ax.add_artist(leg1)

# plt.savefig('figures/f30kTR_selection_gender.pdf', bbox_extra_artists=(leg1,), bbox_inches='tight')
plt.savefig('figures/f30kTR_selection_gender_coco.pdf',bbox_inches='tight')
